# %% [markdown]
# <a href="https://colab.research.google.com/github/kvothemaedre/AI_JComp/blob/main/AutoEncoderModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Autoencoder model for auto-colorization</h1>

# %% [markdown]
# <h2>Library imports</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from keras.layers import Dense, Input, Conv2D, Flatten, Reshape, Conv2DTranspose, Dropout
from keras.models import Model
from tensorflow.keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.datasets import cifar10
from keras import backend as K
import pandas as pd

# %% [markdown]
# <h2>Defining the RGB to Gray Transition function

# %%
#Using cv2.cvtcolor(image, cv2.color_scheme)
#Input coloured image and returned the gray image
def rgb_gray(img):
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray_img

# %% [markdown]
# <h2>Loading Data</h2>

# %%
#Loading the training and testing dataset from Keras datasets
#Here, x_train is our training set and x_test is our validation set
#We do not require the y_train/y_test dataset as we are not performing image classification with target labels
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
#Dimensions of each of the sets
print(x_train.shape)
print(x_test.shape)
#Getting the height, width and number of channels from the image
img_dim = x_train.shape[1]
channels = 3
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# <h2>Displaying sample images from the dataset with their respective class</h2>

# %%
#Display sample images from the dataset
fig, ax = plt.subplots(5,5,sharex=True,sharey=True,figsize=(10,10))
c=0
for i in range(0,5):
    for j in range (0,5):
        ax[i,j].imshow(x_train[c])
        ax[i,j].set_title(y_train[c])
        c=c+1
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# <h2>Conversion process and storing them in a list</h2>

# %%
im1 = x_train[0]
fig, ax = plt.subplots(ncols = 2)
ax[0].imshow(im1)
im2 = cv2.cvtColor(im1, cv2.COLOR_RGB2GRAY)
ax[1].imshow(im2, cmap='gray')

# %%
#Our lists to store the converted images
x_train_Gray = []
x_test_Gray = []
#Iterate over number of images for training set
for i in range(x_train.shape[0]):
 img = x_train[i]
 #convert and append
 x_train_Gray.append(rgb_gray(img))
print(len(x_train_Gray))
# Out:
# 50000

# %%
#Same process for the test images
for i in range(x_test.shape[0]):
 img = x_test[i]
 x_test_Gray.append(rgb_gray(img))
print(len(x_test_Gray))
# Out:
# 10000

# %% [markdown]
# <h2>Image Pre-processing</h2>

# %%
#Convert the given list to a numpy array for input
x_train_Gray = np.asarray(x_train_Gray)
x_test_Gray = np.asarray(x_test_Gray)

#Reshape the given data into (m - no. of samples, height, width, channels)
#We will reshape both the training coloured and gray images - Features and targets
x_train = x_train.reshape(x_train.shape[0], img_dim, img_dim, channels)
x_test = x_test.reshape(x_test.shape[0], img_dim, img_dim, channels)
x_train_Gray = x_train_Gray.reshape(x_train_Gray.shape[0], img_dim,
img_dim, 1)
x_test_Gray = x_test_Gray.reshape(x_test_Gray.shape[0], img_dim,img_dim,1)
input_shape = (img_dim, img_dim, 1)
lat_dim = 256

# %% [markdown]
# <h2>Normalizing pixels over the range [0-1]

# %%
#Dividing each pixel by 255 to get a normalized value
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255
x_train_Gray = x_train_Gray.astype('float32')/255
x_test_Gray = x_test_Gray.astype('float32')/255

# %% [markdown]
# <h2>Example of sample image and converted image (after passing through black and white function)</h2>

# %% [markdown]
# 50000, 32, 32, 3

# %% [markdown]
# <h2>Initialization of the encoder model</h2>

# %%
#ENCODER MODEL
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
x = Conv2D(64, (3, 3), strides=2, activation='relu', padding='same')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu', padding='same')(x)
x = Conv2D(256, (3, 3), strides=2, activation='relu', padding='same')(x)
shape = K.int_shape(x)
x = Flatten()(x)
latent = Dense(256, name='latent_vector')(x)
encoder = Model(inputs, latent, name='encoder_model')
encoder.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               1048832
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Initialization of the decoder model</h2>

# %%
#DECODER MODEL
latent_inputs = Input(shape = (lat_dim,), name = 'decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)
x = Conv2DTranspose(256, (3,3), strides = 2, activation = 'relu', padding= 'same')(x)
x = Conv2DTranspose(128, (3,3), strides = 2, activation = 'relu', padding= 'same')(x)
x = Conv2DTranspose(64, (3,3), strides = 2, activation = 'relu', padding ='same')(x)
outputs = Conv2DTranspose(3, (3,3), activation = 'sigmoid', padding = 'same', name = 'decoder_output')(x)
decoder = Model(latent_inputs, outputs, name = 'decoder_model')
decoder.summary()
# Out:
# Model: "decoder_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 256)]             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              1052672
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       295040
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 64)        73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 32, 32, 3)         1731
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Auto-encoder model</h2>

# %%
#AUTOENCODER MODEL
autoencoder = Model(inputs, decoder(encoder(inputs)), name = 'autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# encoder_model (Functional)   (None, 256)               1418496
# _________________________________________________________________
# decoder_model (Functional)   (None, 32, 32, 3)         2013315
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <h2>Learning rate scheduling and checkpoint callbacks</h2>

# %%
#Learning Rate plateau and scheduling
lr_reducer = ReduceLROnPlateau(factor = np.sqrt(0.1), cooldown = 0, patience = 5, verbose = 1, min_lr = 0.5e-6)
#Preparing save location during model training
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.h5'

#Creating dir to save the model
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
print(filepath)

#Checkpoint and learning rate scheduling callback
checkpoints = ModelCheckpoint(filepath = filepath, monitor = 'val_loss', verbose = 1, save_best_only = True)
callbacks = [lr_reducer]
# Out:
# /content/saved_models/colorized_ae_model.h5

# %% [markdown]
# <h2>Training the model over the given dataset over batches and epochs</h2>

# %%
#TRAINING
#Using the desired loss function, optimizer and metric
autoencoder.compile(loss = "mse", optimizer = 'Adam', metrics = ['accuracy'])
#Fit the model with the training set and validation set
history = autoencoder.fit(x_train_Gray, x_train, validation_data = (x_test_Gray, x_test),epochs = 50, batch_size = 32, callbacks = callbacks)
x_decoded = autoencoder.predict(x_test_Gray)
autoencoder.save('colourization_model.h5')
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 51s 12ms/step - loss: 0.0155 - accuracy: 0.4873 - val_loss: 0.0107 - val_accuracy: 0.4993
# Epoch 2/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0099 - accuracy: 0.5065 - val_loss: 0.0092 - val_accuracy: 0.4739
# Epoch 3/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0088 - accuracy: 0.5144 - val_loss: 0.0086 - val_accuracy: 0.5169
# Epoch 4/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0083 - accuracy: 0.5202 - val_loss: 0.0081 - val_accuracy: 0.4997
# Epoch 5/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0080 - accuracy: 0.5248 - val_loss: 0.0079 - val_accuracy: 0.5240
# Epoch 6/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0077 - accuracy: 0.5297 - val_loss: 0.0077 - val_accuracy: 0.5207
# Epoch 7/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0075 - accuracy: 0.5342 - val_loss: 0.0077 - val_accuracy: 0.5230
# Epoch 8/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0073 - accuracy: 0.5391 - val_loss: 0.0077 - val_accuracy: 0.5228
# Epoch 9/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0071 - accuracy: 0.5428 - val_loss: 0.0074 - val_accuracy: 0.5496
# Epoch 10/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0069 - accuracy: 0.5478 - val_loss: 0.0075 - val_accuracy: 0.5293
# Epoch 11/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0067 - accuracy: 0.5532 - val_loss: 0.0075 - val_accuracy: 0.5418
# Epoch 12/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0064 - accuracy: 0.5579 - val_loss: 0.0078 - val_accuracy: 0.5201
# Epoch 13/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0062 - accuracy: 0.5626 - val_loss: 0.0076 - val_accuracy: 0.5138
# Epoch 14/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0060 - accuracy: 0.5672 - val_loss: 0.0076 - val_accuracy: 0.5154
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# Epoch 15/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0052 - accuracy: 0.5860 - val_loss: 0.0072 - val_accuracy: 0.5201
# Epoch 16/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0050 - accuracy: 0.5922 - val_loss: 0.0073 - val_accuracy: 0.5183
# Epoch 17/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0048 - accuracy: 0.5969 - val_loss: 0.0073 - val_accuracy: 0.5252
# Epoch 18/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0047 - accuracy: 0.6005 - val_loss: 0.0075 - val_accuracy: 0.5249
# Epoch 19/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0046 - accuracy: 0.6041 - val_loss: 0.0074 - val_accuracy: 0.5362
# Epoch 20/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0045 - accuracy: 0.6079 - val_loss: 0.0075 - val_accuracy: 0.5245
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# Epoch 21/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0042 - accuracy: 0.6176 - val_loss: 0.0075 - val_accuracy: 0.5266
# Epoch 22/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0041 - accuracy: 0.6199 - val_loss: 0.0076 - val_accuracy: 0.5223
# Epoch 23/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0041 - accuracy: 0.6215 - val_loss: 0.0075 - val_accuracy: 0.5218
# Epoch 24/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0040 - accuracy: 0.6232 - val_loss: 0.0076 - val_accuracy: 0.5064
# Epoch 25/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0040 - accuracy: 0.6246 - val_loss: 0.0075 - val_accuracy: 0.5184
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# Epoch 26/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0039 - accuracy: 0.6289 - val_loss: 0.0076 - val_accuracy: 0.5108
# Epoch 27/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0039 - accuracy: 0.6294 - val_loss: 0.0076 - val_accuracy: 0.5129
# Epoch 28/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6300 - val_loss: 0.0076 - val_accuracy: 0.5144
# Epoch 29/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6308 - val_loss: 0.0076 - val_accuracy: 0.5120
# Epoch 30/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6312 - val_loss: 0.0076 - val_accuracy: 0.5115
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# Epoch 31/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6326 - val_loss: 0.0076 - val_accuracy: 0.5107
# Epoch 32/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6330 - val_loss: 0.0076 - val_accuracy: 0.5113
# Epoch 33/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6330 - val_loss: 0.0077 - val_accuracy: 0.5101
# Epoch 34/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6333 - val_loss: 0.0077 - val_accuracy: 0.5111
# Epoch 35/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6335 - val_loss: 0.0077 - val_accuracy: 0.5105
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
# Epoch 36/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6338 - val_loss: 0.0077 - val_accuracy: 0.5095
# Epoch 37/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6340 - val_loss: 0.0077 - val_accuracy: 0.5106
# Epoch 38/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6341 - val_loss: 0.0077 - val_accuracy: 0.5100
# Epoch 39/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6341 - val_loss: 0.0077 - val_accuracy: 0.5110
# Epoch 40/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6342 - val_loss: 0.0077 - val_accuracy: 0.5101
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000553323957e-06.
# Epoch 41/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6344 - val_loss: 0.0077 - val_accuracy: 0.5096
# Epoch 42/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6343 - val_loss: 0.0077 - val_accuracy: 0.5102
# Epoch 43/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6344 - val_loss: 0.0077 - val_accuracy: 0.5101
# Epoch 44/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6344 - val_loss: 0.0077 - val_accuracy: 0.5104
# Epoch 45/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6344 - val_loss: 0.0077 - val_accuracy: 0.5100
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 5e-07.
# Epoch 46/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6345 - val_loss: 0.0077 - val_accuracy: 0.5102
# Epoch 47/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6345 - val_loss: 0.0077 - val_accuracy: 0.5103
# Epoch 48/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6345 - val_loss: 0.0077 - val_accuracy: 0.5101
# Epoch 49/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0038 - accuracy: 0.6346 - val_loss: 0.0077 - val_accuracy: 0.5100
# Epoch 50/50
#  431/1563 [=======>......................] - ETA: 51:21 - loss: 0.0037 - accuracy: 0.6340

# %% [markdown]
# <h2>Loading the model and checking out the results</h2>

# %%
from google.colab import files
#files.download('colourization_model.h5')
#Displaying Results
imgs = x_test[:25]
imgs = imgs.reshape((5, 5, img_dim, img_dim, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Original Image')
plt.imshow(imgs, interpolation='none')
#plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()
imgs = x_decoded[:25]
imgs = imgs.reshape((5, 5, img_dim, img_dim, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
#plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()

# %%
plt.imshow(x_decoded[2])

# %%
plt.imshow(x_test[2])

# %%
df = pd.DataFrame(history.history)
df[['accuracy','val_accuracy']].plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.xlabel("epochs")
plt.title('Train and Validation Accuracy')
plt.show()

# %%
df[['val_loss']].plot()
plt.xlabel("epochs")
plt.title('Validation Loss')
plt.show()
#MSE on validation data x_test_gray, x_test

# %%
df[['loss']].plot()
plt.xlabel("epochs")
plt.title('Training Loss')
plt.show()
#MSE on training data x_train_gray, x_train
